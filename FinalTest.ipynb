# %%
# %cd /content/drive/MyDrive/Learn_Colabotary/Learn-Colab
# Out:
# /content/drive/MyDrive/Learn_Colabotary/Learn-Colab

# %%
# !git add .
# !git commit -m "final-test"
# Out:
# [main f81789c] final-test
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 FinalTest.ipynb
#  rewrite TestCode.ipynb (85%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.81 KiB | 115.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dding8838/Learn-Colab.git
#    107e140..f81789c  main -> main

# %%
def calculate_factorial(n):
  if n == 1:
    return 1
  total = n*n-1
  calculate_factorial(n-1)
