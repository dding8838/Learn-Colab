# %%
# %cd /content/drive/MyDrive/Learn_Colabotary/Learn-Colab/

# !git add linear-calculate.ipynb
# !git commit -m 선형대수학-공식
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin main

# %%
#DotProduct 점곱 계산

a = [1,2,3]
b = [4,5,6]
answer = 0

for i in range(0,len(a)):
  answer += (a[i]*b[i])
print(answer)
# Out:
# 32

# %%
#Matrox Multiplication 행렬곱 계산

A = [
    [1, 2],
    [3, 4]
]

B = [
    [5, 6],
    [7, 8]
]

C=[]

total = 0

for i in range(0,len(A)):
  row = []
  for j in range(0,len(A[0])):
    total = 0
    for k in range(0,len(A[0])):
      total += A[i][k]*B[k][j]
    row.append(total)
  C.append(row)

print(C)
# Out:
# [[19, 22], [43, 50]]
